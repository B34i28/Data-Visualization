# %% [markdown]
# # -Libraries
# Seaborn atuomatically install these libraries
# - numpy
# - Scipy
# - pandas
# - matplotlib

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool = sns.load_dataset("iris")
phool
#draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width", data=phool)
plt.show()

# %% [markdown]
# ## Adding Title

# %%
#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
phool = sns.load_dataset("iris")
phool
#draw a line plot
sns.lineplot(x="sepal_length" , y="sepal_width", data=phool)
plt.title("Phoolon ka plot")
plt.show()

# %% [markdown]
# ## Adding Limits

# %%
import seaborn as sns
import matplotlib.pyplot as plt

phool=sns.load_dataset("iris")
phool

sns.lineplot(x="sepal_length", y="sepal_width" , data=phool)
plt.title("Phoolon ka plot")
plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# ## set styles
# - darkgrid
# - whitegrid
# - dark
# - white
# - ticks

# %% [markdown]
# ## Problem
# - given problem in next lineplot is
# - find what is the problem in set_style(style=None , rc=None)
# ## Solution
# - we did not import set style from data sns

# %%
# problem
import seaborn as sns
import matplotlib.pyplot as plt
set_style(style=None , rc=None)

phool=sns.load_dataset("iris")
phool

sns.lineplot(x="sepal_length", y="sepal_width",data=phool)
plt.title("Phoolon ka plot")
sns.set_style("whitegrid")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 set_style(style=None , rc=None)
#       6 phool=sns.load_dataset("iris")
#       7 phool
#
# NameError: name 'set_style' is not defined

# %%
# Solution
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style=None , rc=None)
phool=sns.load_dataset("iris")
phool

sns.lineplot(x="sepal_length", y="sepal_width",data=phool)
plt.title("Phoolon ka plot")
sns.set_style("dark")
plt.show()

# %% [markdown]
# ## Size of figure

# %%
import seaborn as sns
import matplotlib.pyplot as plt

phool=sns.load_dataset("iris")
plt.figure(figsize=(10,6))


sns.lineplot(x="sepal_length", y="sepal_width",data=phool)
plt.title("phoolon ka plot")
plt.show()
